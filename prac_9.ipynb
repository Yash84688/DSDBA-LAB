# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df= sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='sex', y='age', hue='survived', data= titanic)

plt.title('Age Distributionby Gender and Survived ststus')
plt.xlabel('Gender')
plt.ylabel('Age')

plt.show()

# %%
titanic_cleaned= titanic.dropna(subset=['age'])

Q1= titanic_cleaned['age'].quartile(0.25)
Q3= titanic_cleaned['age'].quartile(0.75)
IQR= Q3-Q1

lower_bound= Q1-1.5*IQR
upper_bound= Q3+1.5*IQR
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9288\3063896237.py in ?()
#       1 titanic_cleaned= titanic.dropna(subset=['age'])
#       2
# ----> 3 Q1= titanic_cleaned['age'].quartile(0.25)
#       4 Q3= titanic_cleaned['age'].quartile(0.75)
#       5 IQR= Q3-Q1
#       6
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'quartile'

# %%
titanic_cleaned = titanic.dropna(subset=['survived'])
survival_counts = titanic_cleaned['survived'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(survival_counts, labels=['Did Not Survive', 'Survived'], autopct='%1.1f%%', colors=['#FF6347', '#90EE90'], startangle=90)
plt.title('Survival Distribution in Titanic Dataset')
plt.show()

# %%
titanic_cleaned = titanic.dropna(subset=['age'])
Q1 = titanic_cleaned['age'].quantile(0.25)  
Q3 = titanic_cleaned['age'].quantile(0.75)  
IQR = Q3 - Q1 
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = titanic_cleaned[(titanic_cleaned['age'] < lower_bound) | (titanic_cleaned['age'] > upper_bound)]
print("Outliers:")
print(outliers[['age', 'sex', 'survived']])

plt.figure(figsize=(10, 6))
sns.boxplot(x='sex', y='age', data=titanic_cleaned)
plt.title('Age Distribution with Outliers (Boxplot)')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()
# Out:
# Outliers:
#       age   sex  survived
# 33   66.0  male         0
# 54   65.0  male         0
# 96   71.0  male         0
# 116  70.5  male         0
# 280  65.0  male         0
# 456  65.0  male         0
# 493  71.0  male         0
# 630  80.0  male         1
# 672  70.0  male         0
# 745  70.0  male         0
# 851  74.0  male         0
